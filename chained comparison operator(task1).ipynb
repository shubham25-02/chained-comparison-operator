# %%
3<7<8
# Out:
# True

# %%
7>9>6
# Out:
# False

# %%
7<9 and 9>6
# Out:
# True

# %%
2!=3 and 4<5
# Out:
# True

# %%
3==4 or 5<6
# Out:
# True

# %%
3<2 and 4==4
# Out:
# False

# %%
100==3 or 3>5
# Out:
# False

# %%
100==100 or 3>5
# Out:
# True
